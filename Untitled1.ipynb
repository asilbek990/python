# %% [markdown]
# Dictionary

# %%
a = {}

# %%
students = {
    "name": ["Shaxrux","Asilbek","Sarvar","Sarvar"],
     "age": [17,16,17,17],
     "maktabi":["rus maktab","18-son","1-son","6-son"]
}

# %%
print(students)
# Out:
# {'name': ['Shaxrux', 'Asilbek', 'Sarvar', 'Sarvar'], 'age': [17, 16, 17, 17], 'maktabi': ['rus maktab', '18-son', '1-son', '6-son']}

# %% [markdown]
# # Dict indexing

# %%
print(students["maktabi"])
# Out:
# ['rus maktab', '18-son', '1-son', '6-son']

# %% [markdown]
# * keys()
# * values()
# * items()

# %%
print(students.keys())
# Out:
# dict_keys(['name', 'age', 'maktabi'])

# %%
print(students.values())
# Out:
# dict_values([['Shaxrux', 'Asilbek', 'Sarvar', 'Sarvar'], [17, 16, 17, 17], ['rus maktab', '18-son', '1-son', '6-son']])

# %%
print(students.items())
# Out:
# dict_items([('name', ['Shaxrux', 'Asilbek', 'Sarvar', 'Sarvar']), ('age', [17, 16, 17, 17]), ('maktabi', ['rus maktab', '18-son', '1-son', '6-son'])])
