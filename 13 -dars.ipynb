# %%
append, insert, extend, remove, clear, count, copy, sort, reverse

# %%
savat = []

# %%
while True:
    metod = input("Qaysi metodni ishlatmoqshichisiz? \n").lower()

    if metod == "append":
        mahsulot = input("Mahsulot nomi nima? \n")
        savat.append(mahsulot)
        print("Sotib olingan mahsulot:",savat)
    elif metod == "insert":
          index = int(input("Qaysi pozitsiyaga qoshmoqchisi? Raqam yozing! \n"))
          mahsulot = input("Mahsulot nomi nima? \n")
          savat.i
              
        nsert(index, mahsulot)
          print("Sotib olingan mahsulot:",savat)
    elif metod == "stop":
        print("Dastur to'xtadi")
        break
    else:
        print("Noto'g'ri ma'lumot yozdimgiz!")
# Out:
#   File <string>:13
#     nsert(index, mahsulot)
#                           ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ## Tuple

# %%
a =("kino",24, True )

# %%
print(a)
# Out:
# ('kino', 24, True)
