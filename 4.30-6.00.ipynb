# %% [markdown]
# ## string metodlar
# * upper()
# * lower()
# * title()
# * capitalize()
# * strip()
# * lstrip()
# * rstrip()
# * split()
# * join()
# * replace()
# * find()

# %%
name = "asilbek erkinov"

# %%
isim =input("ismingizni kiriting")
# Out:
# ismingizni kiriting aa

# %%
print(isim)
# Out:
# aa

# %%
print(isim.strip())
print(isim.lstrip())
print(isim.rstrip())
# Out:
# aa
# aa
# aa

# %%
print(name.split())
# Out:
# ['asilbek', 'erkinov']

# %%
print("" .join(isim))
# Out:
# aa

# %%
meva =["limon",'nok','uzum','anor']

# %%
del meva[1]#datani ochirish uchun funksiya

# %%
print(meva)
# Out:
# ['limon', 'uzum', 'anor']

# %% [markdown]
# len royxat ichdagi belgilarni sanaydi

# %%
len(meva)#meva nomli list ichidagi obyekt sanadi
# Out:
# 3

# %%
yosh = [14,15,16,17,18,19,20]

# %%
min(yosh)#listdagi eng kichikini chiqaradi
# Out:
# 14

# %%
max(yosh)#listdagi eng kottani chiqaradi
# Out:
# 20

# %%
kg =[6,6.5,4,7,9]

# %%
sum(kg)#yig'indisini topish
# Out:
# 32.5

# %%
sorted(kg)#o'sish ketma-ketlikini tartiblab chiqaradi
# Out:
# [4, 6, 6.5, 7, 9]

# %% [markdown]
# .sort -- datami o'sish ketma-ketlikini tartiblab saqlaydi.

# %%
kg.sort()

# %%
print(kg)
# Out:
# [4, 6, 6.5, 7, 9]

# %%
kinolar = [ "orgimchak odam","tezlik","taxi","maktab"]
print(kinolar [2])
# Out:
# taxi

# %%
kinolar  = [ "orgimchak odam","tezlik","taxi","maktab"]
kinolar.append("transformerlar")# orqaga bita qoshadi

print(kinolar)
# Out:
# ['orgimchak odam', 'tezlik', 'taxi', 'maktab', 'transformerlar']

# %%
print(kinolar)
# Out:
# ['tezlik', 'taxi', 'maktab']

# %%
kinolar  = [ "orgimchak odam","tezlik","taxi","maktab"]
del kinolar[0]

# %%
kinolar  = [ "orgimchak odam","tezlik","taxi","maktab"]
for kino in kinolar:
    print(kino.upper())
# Out:
# ORGIMCHAK ODAM
# TEZLIK
# TAXI
# MAKTAB

# %%
kinolar  = [ "orgimchak odam","tezlik","taxi","maktab"]
kinolar2 =["joker"]
kinolar_olami= kinolar+kinolar2
for kino in kinolar_olami:
    print(kino.upper())
# Out:
# ORGIMCHAK ODAM
# TEZLIK
# TAXI
# MAKTAB
# JOKER

# %%
#listga boshqa list qoshish .extend()

# %%
kinolar.extend(["betmen","tezlik 2","taxi 5","bitta pamidor yegab kelin"])
print(kinolar)
# Out:
# ['orgimchak odam', 'tezlik', 'taxi', 'maktab', 'transformerlar', 'betmen', 'tezlik 2', 'taxi 5', 'bitta pamidor yegab kelin']

# %% [markdown]
#  biror elementni necha takrorlanganini sanash .count()

# %%
kinolar.count('tezlik')
# Out:
# 1

# %%
raqamlar = [12,32,65,76,67,84,26,96,23,]

# %%
  raqamlar.count(65)
# Out:
# 1

# %% [markdown]
# # Referencing va copy

# %%
raqamlar = [12,32,65,76,67,84,26,96,23,]

# %%
a = raqamlar #referencing
a.append(200)

# %%
print(a)
print(raqamlar)
# Out:
# [12, 32, 65, 76, 67, 84, 26, 96, 23, 20, 200]
# [12, 32, 65, 76, 67, 84, 26, 96, 23, 20, 200]

# %% [markdown]
# ## Tartiblash
# * sort()
# * reverse()

# %%
raqamlar = [12,32,65,76,67,84,26,96,23,]
print (raqamlar)
# Out:
# [12, 32, 65, 76, 67, 84, 26, 96, 23]

# %%
raqamlar.sort(reverse=True)
print (raqamlar)
# Out:
# [96, 84, 76, 67, 65, 32, 26, 23, 12]

# %%
raqamlar = [12,32,65,76,67,84,26,96,23,]
raqamlar.reverse()
print (raqamlar)
# Out:
# [23, 96, 26, 84, 67, 76, 65, 32, 12]

# %% [markdown]
# # Tozalash
# * remove()
# * clear()

# %%
raqamlar = [12,32,65,76,67,84,26,96,23,]
raqamlar.remove(26)

# %%
print(raqamlar)
# Out:
# [12, 32, 65, 76, 67, 84, 96, 23]

# %%
raqamlar.clear()

# %%
print(raqamlar)
# Out:
# []

# %%
num = [9,1,5,3,2,5,4,6]
num = num.copy()

# %%
c.sort(reverse=True)

# %%
num.reverse()

# %%
num.remove(5)

# %%
num.extend([7,8])

# %%
num.sort()
print(f"tartiblangan raqam  {num}")
# Out:
# tartiblangan raqam  [1, 2, 3, 4, 5, 5, 6, 9]

# %%
num.clear()
print(zaxira)
# Out:
# []
