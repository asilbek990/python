# %%
print("Salom")
print('salom')
# Out:
# Salom
# salom

# %%
fan = "Data Analyst"

# %%
print(fan)
# Out:
# Data Analyst

# %%
print(fan.upper())
print(fan.lower())
print(fan.title())
print(fan.capitalize())
# Out:
# DATA ANALYST
# data analyst
# Data Analyst
# Data analyst

# %%
name = input("Ismingizni kriting \n")
surname = input("Familyangizni kriting \n")
age = input("Yoshingizni kriting \n")
# Out:
# Ismingizni kriting: Donoxon
# Familyangizni kriting: Qalandarova

# %%
print(name.title(),surname.title(), "siz hozir", age, "yoshdasiz")

# %% [markdown]
# # metodlar

# %%
#listning faqat oxiriga 1 dona data qo'shiladi
.append()
#listning korsatilgan joyiga data qoshadi
.insert()
#listningoxiriga bir va undan ortiq data qoshing
.extend()

# %%
meva = ["nok","uzum","anor"]

# %%
meva.append("olma")

# %%
print(meva)
# Out:
# ['nok', 'uzum', 'anor', 'olma']

# %%
meva.insert(0,"gilos")

# %%
print(meva)
# Out:
# ['gilos', 'nok', 'uzum', 'anor', 'olma']

# %%
meva.extend(["banan","avaqado",])

# %%
print(meva)
# Out:
# ['gilos', 'nok', 'uzum', 'anor', 'olma', 'banan', 'avaqado']
