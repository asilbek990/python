# %%
while True:
    s=input("Nechta tovar bor?(soni yoki 'dokoni'yozing,'exit - chiqish):").strip()
    if s.lower() in ("dokon","dokon"):
        print("siz 'dokon' yozdingiz - bu maxsus xolat. iltimos yoki 'exit' bilan chiqishingiz mumkin.") continue
        if s.lower() == "exit":
            print("dastur toxtadi. Xayir!")
            break
            try:
                n = int(s)
                if n<=0:
                    print("iltimos 0 dan katta son kiriting.")
                    continue
                    print(f"siz kiritdingiz:{n} ta tovar. Har birining narxini kiriting.")
                    total =0.0
                    for i in range(1,n+1):
                        while True:
                            price_str = input(f"{i}-tovar narxini kiriting (son sifatida):").strip()
                            try:
